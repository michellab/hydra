# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Importing-data" data-toc-modified-id="1.-Importing-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1. Importing data</a></span><ul class="toc-item"><li><span><a href="#1.1.-Complete-FreeSolv-database" data-toc-modified-id="1.1.-Complete-FreeSolv-database-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>1.1. Complete FreeSolv database</a></span></li><li><span><a href="#1.2.-SAMPL4_Guthrie-entires-extracted-from-FreeSolv" data-toc-modified-id="1.2.-SAMPL4_Guthrie-entires-extracted-from-FreeSolv-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>1.2. SAMPL4_Guthrie entires extracted from FreeSolv</a></span></li><li><span><a href="#1.3.-Original-SAMPL4_Gurthrie-extracted-from-SI-in-ref.-[1]" data-toc-modified-id="1.3.-Original-SAMPL4_Gurthrie-extracted-from-SI-in-ref.-[1]-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>1.3. Original SAMPL4_Gurthrie extracted from SI in ref. [1]</a></span></li></ul></li><li><span><a href="#2.-Determining-discrepancy" data-toc-modified-id="2.-Determining-discrepancy-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>2. Determining discrepancy</a></span><ul class="toc-item"><li><span><a href="#The-six-ligands-missing-from-FreeSolv-that-are-not-accounted-for." data-toc-modified-id="The-six-ligands-missing-from-FreeSolv-that-are-not-accounted-for.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>The six ligands missing from FreeSolv that are not accounted for.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # SAMPL4_Guthrie FreeSolv Check
# Determine discrepancies between the SAMPL4_Guthrie data originally published in ref. [1] and the FreeSolv database. The SAMPL4 challenge publication can be found at [2].
#
# [1] J. Comput. Aided Mol. Des., 2014, 28, 151–168, DOI 10.1007/s10822-014-9738-y.
#
# [2] J. Comput. Aided Mol. Des., 2014, 28, 135–150, DOI 10.1007/s10822-014-9718-2.

# %% [markdown]
# ## 1. Importing data
#
# ### 1.1. Complete FreeSolv database

# %%
import pandas as pd

data_loc = 'database.txt'
df1 = pd.read_csv(data_loc, sep='; ', engine='python')

# %% [markdown]
# ### 1.2. SAMPL4_Guthrie entires extracted from FreeSolv

# %%
# SAMPl4_Guthrie experimental reference in FreeSolv.
ref = 'SAMPL4_Guthrie'

# Experimental reference column name.
exp_ref_col = 'experimental reference (original or paper this value was taken from)'

# List comprehension for all SAMPL4_Guthrie entires.
SAMPL4_Guthrie = [df1.iloc[i] for i in range(len(df1))  if df1.loc[i, exp_ref_col] == ref]

# Check the number of ligands found is correct.
print('Number of SAMPL4_Guthrie entires in FreeSolv: {}'.format(len(SAMPL4_Guthrie)))

# DataFrame containing only SAMPL4_Guthrie ligands
df2 = pd.DataFrame(SAMPL4_Guthrie)

# Columns to drop
dropped_columns = ['Mobley group calculated value (GAFF) (kcal/mol)',
                'calculated uncertainty (kcal/mol)', 
                   'calculated reference', 
                   'experimental reference (original or paper this value was taken from)', 
                  'text notes.']

# DataFrame not containing dropped columns for clarity
df2 = df2.drop(dropped_columns, axis=1)

# Rename columns to match Guthrie's SI seen below in section 1.3
df2.columns = ['ID', 'SMILES', 'name', 'Ghyd', 'uncertainty']
df2 = df2.reset_index(drop=True)

# Calculate MW
from rdkit.Chem import MolFromSmiles, Descriptors

MW_dp = 2

MW2 = []
for mol in df2.loc[:, 'SMILES']:
    suppl = MolFromSmiles(mol)
    MW2.append(round(Descriptors.MolWt(suppl), MW_dp))

df2.insert(3, 'MW', MW2)

# Order according to MW
df2 = df2.sort_values('MW')
df2 = df2.reset_index(drop=True)

df2
# Out:
# Number of SAMPL4_Guthrie entires in FreeSolv: 41
#                 ID                                    SMILES  \
# 0   mobley_3211679                                 C1CCC=CC1
# 1   mobley_8883511                              Cc1ccccc1C=O
# 2   mobley_3040612                               CCc1ccccc1C
# 3   mobley_2850833                          c1ccc(c(c1)C=O)O
# 4   mobley_2126135                               CCc1ccccc1O
# 5   mobley_3515580                               COc1ccccc1O
# 6   mobley_7417968                              CCOCCOC(=O)C
# 7   mobley_7913234                           CCCCOC[C@H](C)O
# 8   mobley_2613240                              COc1ccccc1OC
# 9   mobley_5917842                          Cc1ccc(c(c1)OC)O
# 10  mobley_3802803                       CCCCCCO[N+](=O)[O-]
# 11  mobley_5006685                  CC(=C)[C@H]1CCC(=CC1)C=O
# 12  mobley_1160109              C[C@@H]1CC[C@H](CC1=O)C(=C)C
# 13  mobley_7676709                CC1=CC(=O)[C@@H](CC1)C(C)C
# 14  mobley_9653690              CC1=CC[C@H](C[C@@H]1O)C(=C)C
# 15   mobley_486214                           COc1cccc(c1O)OC
# 16  mobley_5616693             C[C@@H]1CC[C@H](C(=O)C1)C(C)C
# 17   mobley_819018                      CC(=CCC/C(=C/CO)/C)C
# 18  mobley_9897248                      CC(=CCC/C(=C\CO)/C)C
# 19  mobley_8337722         C[C@@H]1CC[C@H]([C@@H](C1)O)C(C)C
# 20  mobley_4613090                        c1ccc(cc1)Cn2ccnc2
# 21  mobley_9257453                         c1cc(c(cc1O)Cl)Cl
# 22  mobley_2636578           C(CO[N+](=O)[O-])CO[N+](=O)[O-]
# 23  mobley_3359593                        CCCc1ccc(c(c1)OC)O
# 24  mobley_6102880                       c1ccc(cc1)Oc2ccccc2
# 25  mobley_9741965     C[C@@H](CCO[N+](=O)[O-])O[N+](=O)[O-]
# 26  mobley_4479135                     C=C(c1ccccc1)c2ccccc2
# 27  mobley_2972345                    c1ccc2c(c1)Cc3ccccc3C2
# 28  mobley_4587267  C([C@H]([C@H]([C@@H]([C@@H](CO)O)O)O)O)O
# 29  mobley_6935906              CC(=CCC[C@](C)(C=C)OC(=O)C)C
# 30  mobley_3265457                  COc1cc(c(c(c1O)OC)Cl)C=O
# 31  mobley_6688723                   COc1c(cc(c(c1O)OC)Cl)Cl
# 32  mobley_8052240           c1ccc2c(c1)C(=O)c3cccc(c3C2=O)N
# 33  mobley_5003962           c1ccc2c(c1)C(=O)c3ccc(cc3C2=O)N
# 34   mobley_242480        c1ccc2c(c1)C(=O)c3c(ccc(c3C2=O)N)N
# 35  mobley_4371692        c1ccc2c(c1)C(=O)c3c(ccc(c3C2=O)O)N
# 36  mobley_4936555               Cc1cccc(c1C)Nc2ccccc2C(=O)O
# 37  mobley_6195751              COc1c(c(c(c(c1Cl)C=O)Cl)OC)O
# 38  mobley_1944394               CN(C)CCOC(c1ccccc1)c2ccccc2
# 39  mobley_2316618        c1ccc2c(c1)C(=O)c3cccc(c3C2=O)NCCO
# 40  mobley_5282042            CN(C)CCC=C1c2ccccc2CCc3c1cccc3
#
#                                                  name      MW   Ghyd  \
# 0                                         cyclohexene   82.15   0.14
# 1                                2-methylbenzaldehyde  120.15  -3.93
# 2                             1-ethyl-2-methylbenzene  120.19  -0.85
# 3                               2-hydroxybenzaldehyde  122.12  -4.68
# 4                                       2-ethylphenol  122.17  -5.66
# 5                                     2-methoxyphenol  124.14  -5.94
# 6                               2-ethoxyethyl acetate  132.16  -5.31
# 7                                 1-butoxy-2-propanol  132.20  -5.73
# 8                                1,2-dimethoxybenzene  138.17  -5.33
# 9                            4-methyl-2-methoxyphenol  138.17  -5.80
# 10                                      hexyl nitrate  147.17  -1.66
# 11  4-(1-Methylethenyl)-1-cyclohexene-1-carboxalde...  150.22  -4.09
# 12  (2R,5R)-2-methyl-5-(1-methylethenyl)-cyclohexa...  152.24  -3.75
# 13            6-isopropyl-3-methyl-1-cyclohex-2-enone  152.24  -4.51
# 14  (1S,5R)-2-methyl-5-(1-methylethenyl)-2-cyclohe...  152.24  -4.44
# 15                                2,6-dimethoxyphenol  154.16  -6.96
# 16          (2S,5R)-2-isopropyl-5-methylcyclohexanone  154.25  -2.53
# 17                (2E)-3,7-dimethylocta-2,6-dien-1-ol  154.25  -4.45
# 18                (2Z)-3,7-dimethylocta-2,6-dien-1-ol  154.25  -4.78
# 19        (1R,2S,5R)-2-isopropyl-5-methylcyclohexanol  156.27  -3.20
# 20                                  1-benzylimidazole  158.20  -7.63
# 21                                 3,4-dichlorophenol  163.00  -7.29
# 22                           3-nitrooxypropyl nitrate  166.09  -4.80
# 23                                   4-propylguaiacol  166.22  -5.26
# 24                                     diphenyl ether  170.21  -2.87
# 25                           1,3-bis-(nitrooxy)butane  180.12  -4.29
# 26                                 1,1-diphenylethene  180.25  -2.78
# 27                             9,10-dihydroanthracene  180.25  -3.78
# 28              (2R,3R,4R,5R)-Hexan-1,2,3,4,5,6-hexol  182.17 -23.62
# 29        (3R)-3,7-Dimethylocta-1,6-dien-3-yl acetate  196.29  -2.49
# 30                             2-chlorosyringaldehyde  216.62  -7.78
# 31                   3,5-dichloro-2,6-dimethoxyphenol  223.05  -6.44
# 32                       1-amino-9,10-anthracenedione  223.23  -9.44
# 33                         2-amino-9,10-anthraquinone  223.23 -11.53
# 34                   1,4-diamino-9,10-anthracenedione  238.25 -11.85
# 35             1-amino-4-hydroxy-9,10-anthracenedione  239.23  -9.53
# 36            2-(2,3-dimethylphenyl)aminobenzoic acid  241.29  -6.78
# 37                         2,6-dichlorosyringaldehyde  251.06  -8.68
# 38              [2-benzhydryloxyethyl]-dimethyl-amine  255.36  -9.34
# 39         1-(2-hydroxyethylamino)-9,10-anthraquinone  267.28 -14.21
# 40                                      Amitriptyline  277.41  -7.43
#
#     uncertainty
# 0          0.10
# 1          0.10
# 2          0.10
# 3          0.10
# 4          0.10
# 5          0.10
# 6          0.10
# 7          0.15
# 8          0.10
# 9          0.10
# 10         0.10
# 11         0.17
# 12         0.21
# 13         0.10
# 14         0.43
# 15         0.10
# 16         0.25
# 17         0.24
# 18         0.25
# 19         0.28
# 20         0.12
# 21         0.10
# 22         0.39
# 23         0.18
# 24         0.69
# 25         0.39
# 26         0.10
# 27         0.10
# 28         0.32
# 29         0.85
# 30         0.77
# 31         0.38
# 32         0.74
# 33         0.29
# 34         0.35
# 35         0.28
# 36         0.10
# 37         0.76
# 38         0.62
# 39         1.10
# 40         0.60

# %% [markdown]
# ### 1.3. Original SAMPL4_Gurthrie extracted from SI in ref. [1]

# %%
# DataFrame containing Guthrie SI
df3 = pd.read_csv('sampl4_guthrie.csv')

# Set MW to 2 decimal places
MW3 = []
for mol in df3.loc[:, 'SMILES']:
    suppl = MolFromSmiles(mol)
    MW3.append(round(Descriptors.MolWt(suppl), MW_dp))
df3.loc[:, 'MW'] = MW3

# Order according to MW
df3 = df3.sort_values('MW')
df3 = df3.reset_index(drop=True)

print('Number of entires in Guthrie SI: {}'.format(len(df3)))

df3
# Out:
# Number of entires in Guthrie SI: 47
#            ID                              SMILES  \
# 0   SAMPL4_43                           C1CCC=CC1
# 1   SAMPL4_41                            N1CCCCC1
# 2   SAMPL4_42                            O1CCCCC1
# 3   SAMPL4_44                            O1CCOCC1
# 4   SAMPL4_38                        O=Cc1ccccc1C
# 5   SAMPL4_39                       c1cccc(C)c1CC
# 6   SAMPL4_35                        Oc1ccccc1C=O
# 7   SAMPL4_36                         Oc1ccccc1CC
# 8   SAMPL4_37                       COc1c(cccc1)O
# 9   SAMPL4_26                      C(C)OCCOC(=O)C
# 10  SAMPL4_25                       O(CC(O)C)CCCC
# 11  SAMPL4_34                    Cc1cc(c(cc1)O)OC
# 12   SAMPL4_5                      O(C)c1ccccc1OC
# 13  SAMPL4_30                     O(C(=O)C)CCCCCC
# 14  SAMPL4_29               O([N+](=O)[O-])CCCCCC
# 15  SAMPL4_14             O=C\C1=C\CC(\C(=C)C)CC1
# 16  SAMPL4_13                 OC1CC(CC=C1C)C(C)=C
# 17  SAMPL4_12               CC1C(=O)CC(CC1)C(=C)C
# 18  SAMPL4_15               CC1=CC(=O)C(CC1)C(C)C
# 19  SAMPL4_33                   O(C)c1cccc(OC)c1O
# 20  SAMPL4_17                CC1CCC(C(=O)C1)C(C)C
# 21  SAMPL4_43                OC\C=C(\CCC=C(C)C)/C
# 22   SAMPL4_3                   CC(=CCCC(=CCO)C)C
# 23  SAMPL4_16                   OC1CC(CCC1C(C)C)C
# 24  SAMPL4_21                  c1(ccccc1)Cn2cncc2
# 25  SAMPL4_32                     Clc1cc(O)ccc1Cl
# 26  SAMPL4_27             O(N(=O)=O)C(CCON(=O)=O)
# 27   SAMPL4_6                    Oc1ccc(cc1OC)CCC
# 28  SAMPL4_52                 O(c1ccccc1)c1ccccc1
# 29  SAMPL4_50            c12c(cc3c(c1)cccc3)cccc2
# 30  SAMPL4_28            O(N(=O)=O)C(CCON(=O)=O)C
# 31  SAMPL4_20               C=C(c1ccccc1)c2ccccc2
# 32  SAMPL4_19              C1c2c(Cc3c1cccc3)cccc2
# 33   SAMPL4_1              C(C(C(C(C(CO)O)O)O)O)O
# 34  SAMPL4_49              O1c2c(Oc3c1cccc3)cccc2
# 35   SAMPL4_2           CC(=CCCC(C)(C=C)OC(=O)C)C
# 36  SAMPL4_11            Clc1c(OC)c(O)c(OC)cc1C=O
# 37  SAMPL4_10             Clc1cc(Cl)c(OC)c(O)c1OC
# 38  SAMPL4_46     Nc1c2c(ccc1)C(=O)c3c(cccc3)C2=O
# 39  SAMPL4_45     O=C1c2c(ccc(N)c2)C(=O)c2c1cccc2
# 40  SAMPL4_48    O=C1c2c(C(=O)c3c1cccc3)c(N)ccc2N
# 41  SAMPL4_51  Nc1c2c(c(cc1)O)C(=O)c3c(cccc3)C2=O
# 42  SAMPL4_22         Cc1c(cccc1Nc2ccccc2C(=O)O)C
# 43   SAMPL4_9        Clc1c(C=O)c(Cl)c(OC)c(O)c1OC
# 44  SAMPL4_23         c1ccccc1C(c2ccccc2)OCCN(C)C
# 45  SAMPL4_47    O=C1c2c(cccc2NCCO)C(=O)c2c1cccc2
# 46  SAMPL4_24      CN(C)CCC=C1c2ccccc2CCc3c1cccc3
#
#                                           name      MW   Ghyd  uncertainty
# 0                                  cyclohexene   82.15   0.14         0.10
# 1                                   piperidine   85.15  -5.05         0.10
# 2                              tetrahydropyran   86.13  -3.13         0.10
# 3                                  1,4-dioxane   88.11  -5.08         0.10
# 4                         2-methylbenzaldehyde  120.15  -3.93         0.10
# 5                      1-ethyl-2-methylbenzene  120.19  -0.85         0.10
# 6                        2-hydroxybenzaldehyde  122.12  -4.68         0.10
# 7                                2-ethylphenol  122.17  -5.66         0.10
# 8                              2-methoxyphenol  124.14  -5.94         0.10
# 9                        2-ethoxyethyl acetate  132.16  -5.31         0.10
# 10                         1-butoxy-2-propanol  132.20  -5.73         0.15
# 11                    4-methyl-2-methoxyphenol  138.17  -5.80         0.10
# 12                        1,2-dimethoxybenzene  138.17  -5.33         0.10
# 13                               hexyl acetate  144.21  -2.29         0.12
# 14                               hexyl nitrate  147.17  -1.66         0.10
# 15                            l-perillaldehyde  150.22  -4.09         0.17
# 16                                     carveol  152.24  -4.44         0.43
# 17                              dihydrocarvone  152.24  -3.75         0.21
# 18                                  piperitone  152.24  -4.51         0.10
# 19                         2,6-dimethoxyphenol  154.16  -6.96         0.10
# 20                                    menthone  154.25  -2.53         0.25
# 21                                    geraniol  154.25  -4.45         0.24
# 22                                       nerol  154.25  -4.78         0.25
# 23                                     menthol  156.27  -3.20         0.27
# 24                           1-benzylimidazole  158.20  -7.63         0.12
# 25                          3,4-dichlorophenol  163.00  -7.29         0.10
# 26                   1,3-bis-(nitrooxy)propane  166.09  -4.80         0.39
# 27                            4-propylguaiacol  166.22  -5.26         0.18
# 28                              diphenyl ether  170.21  -2.87         0.69
# 29                                  anthracene  178.23  -4.14         0.10
# 30                    1,3-bis-(nitrooxy)butane  180.12  -4.29         0.39
# 31                          1,1-diphenylethene  180.25  -2.78         0.10
# 32                      9,10-dihydroanthracene  180.25  -3.78         0.10
# 33                                    mannitol  182.17 -23.62         0.32
# 34                            dibenzo-p-dioxin  184.19  -3.16         0.10
# 35                             linalyl acetate  196.29  -2.49         0.85
# 36                      2-chlorosyringaldehyde  216.62  -7.78         0.77
# 37                        3,5-dichlorosyringol  223.05  -6.24         0.38
# 38                  1-amino-9,10-anthraquinone  223.23  -9.44         0.74
# 39                  2-amino-9,10-anthraquinone  223.23 -11.53         0.29
# 40              1,4-diamino-9,10-anthraquinone  238.25 -11.85         0.35
# 41        1-amino-4-hydroxy-9,10-anthraquinone  239.23  -9.53         0.28
# 42                              mefenamic acid  241.29  -6.78         0.10
# 43                  2,6-dichlorosyringaldehyde  251.06  -8.24         0.76
# 44                             diphenhydramine  255.36  -9.34         0.62
# 45  1-(2-hydroxyethylamino)-9,10-anthraquinone  267.28 -14.21         1.10
# 46                               amitriptyline  277.41  -7.43         0.60

# %% [markdown]
# ## 2. Determining discrepancy

# %%
# df2 = SAMPL4_Guthrie extracted from FreeSolv
# df3 = SAMPL4_Guthrie extracted from original SI
dicrepancy = len(df3) - len(df2)
print('Discrepancy between SAMPL4_Gurthire in FreeSolv and SI is:', dicrepancy)
# Out:
# Discrepancy between SAMPL4_Gurthire in FreeSolv and SI is: 6

# %%
df2.head()
# Out:
#                ID            SMILES                     name      MW  Ghyd  \
# 0  mobley_3211679         C1CCC=CC1              cyclohexene   82.15  0.14
# 1  mobley_8883511      Cc1ccccc1C=O     2-methylbenzaldehyde  120.15 -3.93
# 2  mobley_3040612       CCc1ccccc1C  1-ethyl-2-methylbenzene  120.19 -0.85
# 3  mobley_2850833  c1ccc(c(c1)C=O)O    2-hydroxybenzaldehyde  122.12 -4.68
# 4  mobley_2126135       CCc1ccccc1O            2-ethylphenol  122.17 -5.66
#
#    uncertainty
# 0          0.1
# 1          0.1
# 2          0.1
# 3          0.1
# 4          0.1

# %%
df3.head()
# Out:
#           ID        SMILES                  name      MW  Ghyd  uncertainty
# 0  SAMPL4_43     C1CCC=CC1           cyclohexene   82.15  0.14          0.1
# 1  SAMPL4_41      N1CCCCC1            piperidine   85.15 -5.05          0.1
# 2  SAMPL4_42      O1CCCCC1       tetrahydropyran   86.13 -3.13          0.1
# 3  SAMPL4_44      O1CCOCC1           1,4-dioxane   88.11 -5.08          0.1
# 4  SAMPL4_38  O=Cc1ccccc1C  2-methylbenzaldehyde  120.15 -3.93          0.1

# %%
def check_MW(df2, df3):
    """Iterate down MW columns in two dataframes and check if values at the same index
    are equal. If not, a new row of zeros is inserted at the infringing index.
    
    Note: at this point, df3 is the longer dataframe of the two."""
    
    for i, MW1, MW2 in zip(range(len(df3)), df2.loc[:, 'MW'], df3.loc[:, 'MW']):
        if MW1 != MW2 and MW1 != '-':
            start_upper = 0
            end_upper = i
            start_lower = i
            end_lower = df2.shape[0]
            upper_half = [*range(start_upper, end_upper, 1)]
            lower_half = [*range(start_lower, end_lower, 1)]
            lower_half = [x.__add__(1) for x in lower_half]
            index_ = upper_half + lower_half
            df2.index = index_
            df2.loc[i] = '-'
            df2 = df2.sort_index()

            break
    
    return df2

for i in range(len(df3)):
    df2 = check_MW(df2, df3)

# %%
df4 = pd.concat([df2.loc[:, 'MW'], df3.loc[:, 'MW']], axis=1)
df4.columns = ['Freesolv', 'SI']
df4
# Out:
#    Freesolv      SI
# 0     82.15   82.15
# 1         -   85.15
# 2         -   86.13
# 3         -   88.11
# 4    120.15  120.15
# 5    120.19  120.19
# 6    122.12  122.12
# 7    122.17  122.17
# 8    124.14  124.14
# 9    132.16  132.16
# 10    132.2  132.20
# 11   138.17  138.17
# 12   138.17  138.17
# 13        -  144.21
# 14   147.17  147.17
# 15   150.22  150.22
# 16   152.24  152.24
# 17   152.24  152.24
# 18   152.24  152.24
# 19   154.16  154.16
# 20   154.25  154.25
# 21   154.25  154.25
# 22   154.25  154.25
# 23   156.27  156.27
# 24    158.2  158.20
# 25      163  163.00
# 26   166.09  166.09
# 27   166.22  166.22
# 28   170.21  170.21
# 29        -  178.23
# 30   180.12  180.12
# 31   180.25  180.25
# 32   180.25  180.25
# 33   182.17  182.17
# 34        -  184.19
# 35   196.29  196.29
# 36   216.62  216.62
# 37   223.05  223.05
# 38   223.23  223.23
# 39   223.23  223.23
# 40   238.25  238.25
# 41   239.23  239.23
# 42   241.29  241.29
# 43   251.06  251.06
# 44   255.36  255.36
# 45   267.28  267.28
# 46   277.41  277.41

# %% [markdown]
# ### The six ligands missing from FreeSolv that are not accounted for.

# %%
discrepancy = []
for i, mol in zip(range(len(df2)), df2.loc[:, 'ID']):
    if mol == '-':
        discrepancy.append(df3.loc[i, :])
df5 = pd.DataFrame(discrepancy)
df5
# Out:
#            ID                    SMILES              name      MW  Ghyd  \
# 1   SAMPL4_41                  N1CCCCC1        piperidine   85.15 -5.05
# 2   SAMPL4_42                  O1CCCCC1   tetrahydropyran   86.13 -3.13
# 3   SAMPL4_44                  O1CCOCC1       1,4-dioxane   88.11 -5.08
# 13  SAMPL4_30           O(C(=O)C)CCCCCC     hexyl acetate  144.21 -2.29
# 29  SAMPL4_50  c12c(cc3c(c1)cccc3)cccc2        anthracene  178.23 -4.14
# 34  SAMPL4_49    O1c2c(Oc3c1cccc3)cccc2  dibenzo-p-dioxin  184.19 -3.16
#
#     uncertainty
# 1          0.10
# 2          0.10
# 3          0.10
# 13         0.12
# 29         0.10
# 34         0.10

# %% [markdown]
# A consideration for the discrepancy was existance of the ligand alreeady in the FreeSolv database.

# %%
# Write SMILES to lists
freesolv_smi = df1['SMILES'].tolist()
discrep_smi = df5['SMILES'].tolist()

# Pairwise comparison between discrepancy set and FreeSolv
check_lst = [smi1 == smi2 for smi1 in freesolv_smi for smi2 in discrep_smi]
any(check_lst)
# Out:
# False
